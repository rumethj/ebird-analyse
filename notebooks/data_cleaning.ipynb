# %% [markdown]
# # EBird Data Cleaning And Exploration

# %% [markdown]
# Required packages and Set Up

# %%
# Additional : 
# Trip advisor Review: https://www.kaggle.com/datasets/poojaillangarathne/sri-lankan-hotel-reviews
# Travel Destination Google Review: https://www.kaggle.com/datasets/nethumdperera/travel-destinations-reviews-in-sri-lanka

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys

# Add parent directory to path to import data_handler module
# The notebook is in notebooks/ directory, so we need to go up one level to get project root
project_root = os.path.dirname(os.getcwd())
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
import os
# Test cell - if you see this output, execution is working!
print("✓ Notebook is executing!")
print(f"Current working directory: {os.getcwd()}")
print(f"Python version check: OK")
# Out:
# ✓ Notebook is executing!
# Current working directory: /Users/ruwanjayasinghe/Documents/Rumeth/UCL/data_science/notebooks
# Python version check: OK

# %% [markdown]
# Load the data

# %%
from data_handler import collect_checklists_data_async

# Call async function and await the result
checklist_df = await collect_checklists_data_async()

# print(checklist_df.head())
print(checklist_df.shape)
# Null check
print(checklist_df.info())
# Out:
# (24346, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24346 entries, 0 to 24345
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   isoObsDate       24346 non-null  object
#  1   loc              24346 non-null  object
#  2   locId            24346 non-null  object
#  3   numSpecies       24346 non-null  int64
#  4   obsDt            24346 non-null  object
#  5   obsTime          24279 non-null  object
#  6   subID            24346 non-null  object
#  7   subId            24346 non-null  object
#  8   userDisplayName  24345 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.7+ MB
# None

# %%
# Check Null rows
null_mask = checklist_df.isnull().any(axis=1)
null_data = checklist_df[null_mask]
print(null_data)
# Out:
#              isoObsDate                                                loc  \
# 4299   2020-03-05 00:00  {'locId': 'L5400563', 'name': 'Sinharaja NP--K...
# 4505   2020-03-27 00:00  {'locId': 'L15943323', 'name': 'Bellankadawala...
# 4506   2020-03-27 00:00  {'locId': 'L16674761', 'name': 'Rajanaganaya W...
# 4507   2020-03-27 00:00  {'locId': 'L16674770', 'name': 'Thambuththegam...
# 4573   2020-04-03 00:00  {'locId': 'L16674770', 'name': 'Thambuththegam...
# ...                 ...                                                ...
# 20701  2019-10-29 00:00  {'locId': 'L1122646', 'name': 'Kandy--general ...
# 20702  2019-10-29 00:00  {'locId': 'L4526168', 'name': 'Wilpattu Nation...
# 20705  2019-10-30 00:00  {'locId': 'L4526168', 'name': 'Wilpattu Nation...
# 20739  2019-11-04 00:00  {'locId': 'L10560240', 'name': 'Colombo', 'lat...
# 20846  2019-11-16 00:00  {'locId': 'L936705', 'name': 'Victoria Park', ...
#
# ...

# %%
# unique values of subID
count_unique_id = len(checklist_df["subId"].unique())
print(count_unique_id)
# Out:
# 24346

# %%
# Lets see 
sample = checklist_df["numSpecies"]
sample.describe()
# Out:
# count    24346.000000
# mean        14.420315
# std         13.283851
# min          0.000000
# 25%          4.250000
# 50%         11.000000
# 75%         21.000000
# max        141.000000
# Name: numSpecies, dtype: float64
